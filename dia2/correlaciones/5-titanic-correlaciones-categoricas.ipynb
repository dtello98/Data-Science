# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11, 9.4)

titanic_df = sns.load_dataset('titanic')
titanic_df.dropna(inplace=True)
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %%
titanic_df['sex'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
titanic_df['embarked'].unique()
# Out:
# array(['C', 'S', 'Q'], dtype=object)

# %%
titanic_df['class'].unique()
# Out:
# ['First', 'Third', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
titanic_df['who'].unique()
# Out:
# array(['woman', 'man', 'child'], dtype=object)

# %%
titanic_df['deck'].unique()
# Out:
# ['C', 'E', 'G', 'D', 'A', 'B', 'F']
# Categories (7, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
titanic_df['embark_town'].unique()
# Out:
# array(['Cherbourg', 'Southampton', 'Queenstown'], dtype=object)

# %%
titanic_df['alive'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %% [markdown]
# # LABEL ENCODING

# %%
df_encoded = titanic_df.copy()

# %%
df_encoded['numeric_sex'] = df_encoded['sex'].map({'female':0,'male':1})
df_encoded
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone  numeric_sex
# ...

# %%
df_encoded['numeric_alive'] = df_encoded['alive'].map({'no':0,'yes':1})
df_encoded
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
# ...

# %%
df_encoded = pd.get_dummies(df_encoded,columns=['embarked','class','who','deck','embark_town'],prefix='numeric',dtype=int)
df_encoded
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare  adult_male alive  \
# 1           1       1  female  38.0      1      0  71.2833       False   yes
# 3           1       1  female  35.0      1      0  53.1000       False   yes
# 6           0       1    male  54.0      0      0  51.8625        True    no
# 10          1       3  female   4.0      1      1  16.7000       False   yes
# 11          1       1  female  58.0      0      0  26.5500       False   yes
# ..        ...     ...     ...   ...    ...    ...      ...         ...   ...
# 871         1       1  female  47.0      1      1  52.5542       False   yes
# 872         0       1    male  33.0      0      0   5.0000        True    no
# 879         1       1  female  56.0      0      1  83.1583       False   yes
# 887         1       1  female  19.0      0      0  30.0000       False   yes
# 889         1       1    male  26.0      0      0  30.0000        True   yes
#
# ...

# %%
sns.heatmap(
    data=df_encoded.corr(numeric_only=True),
    cmap=sns.diverging_palette(20,230,as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    cbar_kws={'shrink':0.5},
    annot=True
)
# Out:
# <Axes: >

# %%
corr_matrix = df_encoded.corr(numeric_only=True)
corr_age = corr_matrix[['numeric_alive']].sort_values(by='numeric_alive',ascending=False)
sns.heatmap(
    data=corr_age,
    cmap=sns.diverging_palette(20, 230, as_cmap=True),
    center=0,
    vmin=-1,
    vmax=1,
    linewidths=0.5,
    cbar_kws={'shrink': 0.5},
    annot=True
)
# Out:
# <Axes: >
