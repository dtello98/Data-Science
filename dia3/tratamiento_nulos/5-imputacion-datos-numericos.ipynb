# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %run '/content/pandas_missing_extension.ipynb'

# %%
titanic_df = sns.load_dataset('titanic')
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import missingno

titanic_df.missing.sort_variables_by_missingness().pipe(missingno.matrix)
# Out:
# <Axes: >

# %% [markdown]
# # IMPUTACIÓN DE VARIABLES NÚMERICAS

# %%
titanic_df.dtypes
# Out:
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# who              object
# adult_male         bool
# deck           category
# embark_town      object
# alive            object
# alone              bool
# dtype: object

# %% [markdown]
# # IMPUTACIÓN POR MEDIDAS DE TENDENCIA CENTRAL

# %% [markdown]
# # IMPUTACIÓN DE VARIABLE AGE

# %% [markdown]
# ## MEDIA DE EDAD

# %%
round(titanic_df['age'].mean())
# Out:
# 30

# %%
df_age_mean = titanic_df.copy()
df_age_mean['age'] = df_age_mean['age'].fillna(round(titanic_df['age'].mean()))

# %%
df_age_mean.missing.missing_variable_plot()

# %% [markdown]
# # VALIDAMOS LA IMPUTACIÓN

# %%
print('VALIDAMOS MEDIA DE AGE')
print(f'media original : {round(titanic_df["age"].mean())}')
print(f'media sin nulos : {round(df_age_mean["age"].mean())}')
# Out:
# VALIDAMOS MEDIA DE AGE
# media original : 30
# media sin nulos : 30

# %% [markdown]
# ## MEDIANA

# %%
df_age_median = titanic_df.copy()
df_age_median['age'] = df_age_median['age'].fillna(round(titanic_df['age'].median()))

# %%
print('VALIDAMOS MEDIAN DE AGE')
print(f'median original : {round(titanic_df["age"].median())}')
print(f'median sin nulos : {round(df_age_median["age"].median())}')
# Out:
# VALIDAMOS MEDIAN DE AGE
# median original : 28
# median sin nulos : 28
