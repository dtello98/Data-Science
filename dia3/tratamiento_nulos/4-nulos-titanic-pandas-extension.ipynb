# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %run '/content/pandas_missing_extension.ipynb'

# %%
titanic_df = sns.load_dataset('titanic')
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic_df.missing.number_missing()
# Out:
# np.int64(869)

# %%
titanic_df.missing.missing_variable_summary()
# Out:
#        variable  n_missing  n_cases  pct_missing
# 0      survived          0      891     0.000000
# 1        pclass          0      891     0.000000
# 2           sex          0      891     0.000000
# 3           age        177      891    19.865320
# 4         sibsp          0      891     0.000000
# 5         parch          0      891     0.000000
# 6          fare          0      891     0.000000
# 7      embarked          2      891     0.224467
# 8         class          0      891     0.000000
# 9           who          0      891     0.000000
# 10   adult_male          0      891     0.000000
# 11         deck        688      891    77.216611
# 12  embark_town          2      891     0.224467
# 13        alive          0      891     0.000000
# 14        alone          0      891     0.000000

# %%
titanic_df.missing.missing_variable_plot()

# %%
titanic_df.missing.missing_case_plot()

# %% [markdown]
# # GRAFICAMOS PROPORCIÓN DE DATOS FALTANTES

# %%
import missingno

# %%
titanic_df.missing.sort_variables_by_missingness().pipe(missingno.matrix)
# Out:
# <Axes: >
