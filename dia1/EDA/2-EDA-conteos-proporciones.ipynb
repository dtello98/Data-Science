# %% [markdown]
# # EDA - CONTEOS Y PROPORCIONES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11, 9.4)

penguin_color = {
    'Adelie': '#ff6602ff',
    'Gentoo': '#0f7175ff',
    'Chinstrap': '#c65dc9ff'
}



penguins_df = sns.load_dataset('penguins')
penguins_df.dropna(inplace=True)
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# # CONTEOS
# ## CONTEO DE TODAS LAS VARIABLES

# %%
penguins_df.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      333     333      333.000000     333.000000         333.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       146     163             NaN            NaN                NaN
# mean       NaN     NaN       43.992793      17.164865         200.966967
# std        NaN     NaN        5.468668       1.969235          14.015765
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.500000      15.600000         190.000000
# 50%        NaN     NaN       44.500000      17.300000         197.000000
# 75%        NaN     NaN       48.600000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex
# count    333.000000   333
# unique          NaN     2
# ...

# %% [markdown]
# # CONTEO DE VARIABLES CATEGORICAS

# %%
penguins_df.describe(include=object)
# Out:
#        species  island   sex
# count      333     333   333
# unique       3       3     2
# top     Adelie  Biscoe  Male
# freq       146     163   168

# %% [markdown]
# # CONTEO DE VARIABLES NUMERICAS

# %%
penguins_df.describe(include=[np.number])
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# # GRAFICO DE CONTEOS

# %%
(
    penguins_df
    .species
    .value_counts()
    .plot(
        kind='bar',
        color=penguin_color.values(),
        title='Cantidad de Pinguinos por Especie'
    )
)
# Out:
# <Axes: title={'center': 'Cantidad de Pinguinos por Especie'}, xlabel='species'>

# %% [markdown]
# # grafico de conteo por Islas

# %%
island_color = {
    'Biscoe': '#ff3302ff',
    'Dream': '#0f7175ff',
    'Torgersen': '#c65dc9ff'
}

# %%
(
    penguins_df
    .island
    .value_counts()
    .plot(
        kind='bar',
        color=island_color.values(),
        title='Cantidad de Pinguinos por Isla'
    )
)
# Out:
# <Axes: title={'center': 'Cantidad de Pinguinos por Isla'}, xlabel='island'>

# %% [markdown]
# # PROPORCIONES

# %%
penguins_df['variable'] = ''
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex variable
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
(
    penguins_df
    .pipe(
        lambda df:(
            sns.displot(
                data=df,
                x='variable',
                hue='species',
                multiple='fill',
                palette=penguin_color
            )
        )
    )
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-914117605.py in <cell line: 0>()
#       1 (
#       2     penguins_df
# ----> 3     .pipe(
#       4         lambda df:(
#       5             sns.displot(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in pipe(self, func, *args, **kwargs)
#    6229         if using_copy_on_write():
#    6230             return common.pipe(self.copy(deep=None), func, *args, **kwargs)
# -> 6231         return common.pipe(self, func, *args, **kwargs)
#    6232
#    6233     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/common.py in pipe(obj, func, *args, **kwargs)
#     500         return func(*args, **kwargs)
#     501     else:
# --> 502         return func(obj, *args, **kwargs)
#     503
#     504
#
# ...

# %% [markdown]
# # PROPORCIONES POR ISLA

# %%
(
    penguins_df
    .pipe(
        lambda df:(
            sns.displot(
                data=df,
                x='variable',
                hue='island',
                multiple='fill',
                palette=island_color
            )
        )
    )
)
