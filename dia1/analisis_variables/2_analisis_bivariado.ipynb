# %% [markdown]
# ## 🔗 Análisis Bivariado
#
# ### 🔹 Definición
# El **análisis bivariado** examina la relación entre dos variables, buscando asociaciones o dependencias.
#
# ### 🔹 Tipos de relaciones
# 1. **Numérica vs Numérica:** se evalúa correlación.
# 2. **Numérica vs Categórica:** se comparan medias o medianas.
# 3. **Categórica vs Categórica:** se usa una tabla de contingencia y pruebas de independencia (como Chi-cuadrado).
#
# ### 🔹 Correlación
# La **correlación** mide la fuerza y dirección de una relación lineal entre dos variables numéricas.
#
# - Rango: −1 ≤ *r* ≤ 1
#   - *r* ≈ 1 → relación positiva fuerte
#   - *r* ≈ 0 → sin relación lineal
#   - *r* ≈ −1 → relación negativa fuerte
#
# **Coeficiente de Pearson:**
# > r = Σ((xᵢ−x̄)(yᵢ−ȳ)) / √(Σ(xᵢ−x̄)² × Σ(yᵢ−ȳ)²)
#
# ### 🔹 Visualizaciones típicas
# - **Scatterplot (dispersión):** muestra la relación entre dos variables numéricas.
# - **Heatmap:** representa correlaciones múltiples en una matriz de colores.
# - **Barplot / Boxplot:** compara grupos según una variable categórica.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style(style='whitegrid')
sns.set_context(context='notebook')
plt.rcParams['figure.figsize'] = (11, 9.4)

penguin_color = {
    'Adelie': '#ff6602ff',
    'Gentoo': '#0f7175ff',
    'Chinstrap': '#c65dc9ff'
}

penguins_df = sns.load_dataset('penguins')
penguins_df.dropna(inplace=True)
penguins_df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# # 1 - RELACIONES ENTRE 2 VARIABLES NÚMERICAS

# %%
sns.scatterplot(
    data=penguins_df,
    x='bill_length_mm',
    y='bill_depth_mm',
    alpha=1/2,
    s=100
)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(
    data=penguins_df,
    x='flipper_length_mm',
    y='body_mass_g',
    alpha=1/2,
    s=100
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %%
sns.scatterplot(
    data=penguins_df,
    x='flipper_length_mm',
    y='body_mass_g',
    hue='species',
    alpha=1/2,
    s=100
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='body_mass_g'>

# %% [markdown]
#  # DISPLOT

# %%
sns.displot(
    data=penguins_df,
    x='bill_length_mm',
    y='body_mass_g',
    rug=True
)

# %%
sns.displot(
    data=penguins_df,
    x='flipper_length_mm',
    y='body_mass_g',
    rug=True
)

# %%
sns.displot(
    data=penguins_df,
    x='bill_length_mm',
    y='body_mass_g',
    rug=True,
    kind='kde'
)

# %% [markdown]
# # 2 - RELACIÓN ENTRE VARIABLES CATEGORICAS Y NÚMERICAS

# %% [markdown]
# # RELACIÓN ENTRE FLIPPER_LENGTH_MM Y SPECIES

# %%
sns.scatterplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color,
    alpha=1/2,
    s=100
)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# ## GENERAMOS RUIDO EN LOS VALORES PARA UNA MEJOR VISUALIZACIÓN

# %%
sns.stripplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color
)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# ## UTILIZAMOS BOXPLOT PARA VER EL RANGO

# %%
sns.boxplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color,
    whis=np.inf
)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %%
sns.stripplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color,
    color='.3'
)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %%
sns.boxplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color,
    whis=np.inf
)
sns.stripplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    color='.3'
)
plt.show()
# Out:
# /tmp/ipython-input-757169127.py:9: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:.3'` for the same effect.
#
#   sns.stripplot(

# %% [markdown]
# ## USAMOS VIOLINPLOT PARA TENER UN GRAFICO MAS EXACTO

# %%
sns.violinplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette='dark:.8'
)

sns.stripplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color
)

plt.show()

# %% [markdown]
# ## USAMOS SWARMPLOT PARA UNA DISTRIBUCIÓN MAS UNIFORME

# %%
sns.swarmplot(
    data=penguins_df,
    x='species',
    y='flipper_length_mm',
    hue='species',
    palette=penguin_color
)
# Out:
# <Axes: xlabel='species', ylabel='flipper_length_mm'>

# %% [markdown]
# # VARIABLE CATEGORICA VS CATEGORICA

# %% [markdown]
# ## Prueba Chi-cuadrado de Independencia
#
# Determina si dos variables **categóricas** están asociadas.
#
# **Hipótesis:**
# - H₀: no hay relación (independencia).
# - H₁: hay relación (dependencia).
#
# **Criterio:**
# - Si **p-value < 0.05** → existe relación significativa.
# - Si **p-value ≥ 0.05** → las variables son independientes.
#
# ✅ **Valor óptimo:**
# p < 0.05 → asociación estadística entre las categorías.

# %%
from scipy.stats import chi2_contingency
cat1 = 'species'
cat2 = 'sex'

# %% [markdown]
# ## 1 - CREAMOS TABLA DE CONTINGENCIA

# %%
import pandas as pd
tabla = pd.crosstab(penguins_df[cat1],penguins_df[cat2])
tabla
# Out:
# sex        Female  Male
# species
# Adelie         73    73
# Chinstrap      34    34
# Gentoo         58    61

# %% [markdown]
# ## 2 - CREAMOS GRÁFICO DE BARRAS APILADAS

# %%
tabla.plot(kind='bar',stacked=True)
plt.title(f'Distribución conjunta de {cat1} y {cat2}')
plt.xlabel(cat1)
plt.ylabel("Frecuencia")
plt.legend(title=cat2)
plt.show()

# %% [markdown]
# ## 3. Prueba de Chi-cuadrado de independencia

# %%
chi2,p,dof,excepted = chi2_contingency(tabla)
print("\n🧪 Prueba Chi-cuadrado de independencia")
print(f"Chi-cuadrado: {chi2:.3f}")
print(f"Grados de libertad: {dof}")
print(f"p-value: {p:.5f}")
# Out:
# 🧪 Prueba Chi-cuadrado de independencia
# Chi-cuadrado: 0.049
# Grados de libertad: 2
# p-value: 0.97599

# %%
if p < 0.05:
    interpretacion_chi = "Existe evidencia de asociación entre las dos variables categóricas."
else:
    interpretacion_chi = "No hay evidencia suficiente de asociación; las variables pueden considerarse independientes."

print(f"🧩 Interpretación: {interpretacion_chi}")
# Out:
# 🧩 Interpretación: No hay evidencia suficiente de asociación; las variables pueden considerarse independientes.
